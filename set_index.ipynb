# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\wj\AppData\Roaming\Python\Python37\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.8' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
df = pd.DataFrame([('bird', 389.0),
                   ('bird', 24.0),
                   ('mammal', 80.5),
                  ('mammal', np.nan)],
                 index=['falcon', 'parrot', 'lion', 'monkey'],
                columns=('class', 'max_speed'))
df
# Out:
#          class  max_speed
# falcon    bird      389.0
# parrot    bird       24.0
# lion    mammal       80.5
# monkey  mammal        NaN

# %%
df.reset_index()
# Out:
#     index   class  max_speed
# 0  falcon    bird      389.0
# 1  parrot    bird       24.0
# 2    lion  mammal       80.5
# 3  monkey  mammal        NaN

# %%
df.reset_index(drop=True)
# Out:
#     class  max_speed
# 0    bird      389.0
# 1    bird       24.0
# 2  mammal       80.5
# 3  mammal        NaN

# %%
index = pd.MultiIndex.from_tuples([('bird', 'falcon'),
                                    ('bird', 'parrot'),
                                    ('mammal', 'lion'),
                                    ('mammal', 'monkey')],
                                    names=['class', 'name'])
columns = pd.MultiIndex.from_tuples([('speed', 'max'),
                                     ('species', 'type')])

df = pd.DataFrame([(389.0, 'fly'),
                  ( 24.0, 'fly'),
                  ( 80.5, 'run'),
                  (np.nan, 'jump')],
                  index=index,
                  columns=columns)
df
# Out:
#                speed species
#                  max    type
# class  name
# bird   falcon  389.0     fly
#        parrot   24.0     fly
# mammal lion     80.5     run
#        monkey    NaN    jump

# %% [markdown]
# Using the `names` parameter, choose a name for the index column:

# %%
df.reset_index(names=['classes','names'])

# %%
df.reset_index(level='class')
# Out:
#          class  speed species
#                   max    type
# name
# falcon    bird  389.0     fly
# parrot    bird   24.0     fly
# lion    mammal   80.5     run
# monkey  mammal    NaN    jump

# %%
df.reset_index(level='class', col_level=1)
# Out:
#                 speed species
#          class    max    type
# name
# falcon    bird  389.0     fly
# parrot    bird   24.0     fly
# lion    mammal   80.5     run
# monkey  mammal    NaN    jump

# %%
df.reset_index(level='class', col_level=1, col_fill='species')
# Out:
#        species  speed species
#          class    max    type
# name
# falcon    bird  389.0     fly
# parrot    bird   24.0     fly
# lion    mammal   80.5     run
# monkey  mammal    NaN    jump

# %%
df.reset_index(level='class', col_level=1, col_fill='genus')
# Out:
#          genus  speed species
#          class    max    type
# name
# falcon    bird  389.0     fly
# parrot    bird   24.0     fly
# lion    mammal   80.5     run
# monkey  mammal    NaN    jump

# %%
df
# Out:
#                speed species
#                  max    type
# class  name
# bird   falcon  389.0     fly
#        parrot   24.0     fly
# mammal lion     80.5     run
#        monkey    NaN    jump

# %%
df.reset_index(level=['class','name'],col_level=1, col_fill='genus')
# Out:
#     genus          speed species
#     class    name    max    type
# 0    bird  falcon  389.0     fly
# 1    bird  parrot   24.0     fly
# 2  mammal    lion   80.5     run
# 3  mammal  monkey    NaN    jump

# %%
df.reset_index(col_level=0, col_fill='genus')
# Out:
#     class    name  speed species
#     genus   genus    max    type
# 0    bird  falcon  389.0     fly
# 1    bird  parrot   24.0     fly
# 2  mammal    lion   80.5     run
# 3  mammal  monkey    NaN    jump
